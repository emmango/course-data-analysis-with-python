# %%
# Khái báo thư viện
import numpy as np
import pandas as pd
import matplotlib as plt
print("Khai báo thư viện thành công")

# %%
#Nhập dữ liệu từ ổ cứng
data = pd.read_csv('subset-covid-data.csv', header=0, encoding = "ISO-8859-1")  

data
# Out:
#          country continent        date  day  month  year  cases  deaths  \
# 0    Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1        Albania    Europe  2020-04-12   12      4  2020     17       0
# 2        Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3        Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4         Angola    Africa  2020-04-12   12      4  2020      0       0
# ..           ...       ...         ...  ...    ...   ...    ...     ...
# 201    Venezuela   America  2020-04-12   12      4  2020      0       0
# 202      Vietnam      Asia  2020-04-12   12      4  2020      4       0
# 203        Yemen      Asia  2020-04-12   12      4  2020      0       0
# 204       Zambia    Africa  2020-04-12   12      4  2020      0       0
# 205     Zimbabwe    Africa  2020-04-12   12      4  2020      3       0
#
#     country_code  population
# 0            AFG  37172386.0
# 1            ALB   2866376.0
# ...

# %%
# Số lượng dòng và cột của bộ dữ liệu
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       206 non-null    object
#  1   continent     206 non-null    object
#  2   date          206 non-null    object
#  3   day           206 non-null    int64
#  4   month         206 non-null    int64
#  5   year          206 non-null    int64
#  6   cases         206 non-null    int64
#  7   deaths        206 non-null    int64
#  8   country_code  202 non-null    object
#  9   population    202 non-null    float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 16.2+ KB

# %%
# Tìm hiểu xem dữ liệu được thống kê cho những ngày nào
data.date.value_counts()
# Out:
# 2020-04-12    204
# 2020-01-18      1
# 2020-04-11      1
# Name: date, dtype: int64

# %%
data.head(2)
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0

# %%
# lọc dữ liệu nhiễu:
cleaned_data = data[data.cases == 0]
cleaned_data
# Out:
#                                         country continent        date  day  \
# 4                                        Angola    Africa  2020-04-12   12
# 5                                      Anguilla   America  2020-04-12   12
# 6                           Antigua_and_Barbuda   America  2020-04-12   12
# 20                                        Benin    Africa  2020-04-12   12
# 22                                       Bhutan      Asia  2020-04-12   12
# 24            Bonaire, Saint Eustatius and Saba   America  2020-04-12   12
# 26                                     Botswana    Africa  2020-04-12   12
# 28                       British_Virgin_Islands   America  2020-04-12   12
# 29                            Brunei_Darussalam      Asia  2020-04-12   12
# 37   Cases_on_an_international_conveyance_Japan     Other  2020-01-18   18
# 39                     Central_African_Republic    Africa  2020-04-12   12
# ...
